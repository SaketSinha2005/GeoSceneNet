# %%
import sys, os
sys.path.append(os.path.abspath("../src"))

# %%
from data import load_dataset
from model import build_mlp
# Out:
# D:\GeoSceneNet\.venv\Lib\site-packages\keras\src\export\tf2onnx_lib.py:8: FutureWarning: In the future `np.object` will be defined as the corresponding NumPy scalar.
#   if not hasattr(np, "object"):

# %%
DATA_DIR = "D:\\GeoSceneNet\\data\\seg_train"   

train_df, val_df, class_names = load_dataset(
    data_dir=DATA_DIR,
    img_size=(150, 150),
    batch_size=32
)
# Out:
# Found 14034 files belonging to 6 classes.
# Using 11228 files for training.
# Found 14034 files belonging to 6 classes.
# Using 2806 files for validation.

# %%
model, normalizor = build_mlp(learning_rate=1e-3, input_shape=(150, 150, 3), num_classes=6)
train_X = train_df.map(lambda x,y:x)
# Out:
# D:\GeoSceneNet\.venv\Lib\site-packages\keras\src\layers\preprocessing\data_layer.py:95: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)

# %%
normalizor.adapt(train_X)
history = model.fit(
    train_df, 
    validation_data=val_df,
    epochs=15
)
# Out:
# Epoch 1/15
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 15s 38ms/step - accuracy: 0.4260 - loss: 1.6600 - val_accuracy: 0.4718 - val_loss: 1.3393
# Epoch 2/15
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 12s 33ms/step - accuracy: 0.5110 - loss: 1.2788 - val_accuracy: 0.5271 - val_loss: 1.2360
# Epoch 3/15
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 12s 33ms/step - accuracy: 0.5647 - loss: 1.1468 - val_accuracy: 0.5574 - val_loss: 1.1887
# Epoch 4/15
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 12s 33ms/step - accuracy: 0.5947 - loss: 1.0540 - val_accuracy: 0.5467 - val_loss: 1.1932
# Epoch 5/15
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 11s 32ms/step - accuracy: 0.6338 - loss: 0.9777 - val_accuracy: 0.5699 - val_loss: 1.1654
# Epoch 6/15
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 12s 33ms/step - accuracy: 0.6608 - loss: 0.9063 - val_accuracy: 0.5727 - val_loss: 1.1739
# Epoch 7/15
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 11s 32ms/step - accuracy: 0.6866 - loss: 0.8412 - val_accuracy: 0.5788 - val_loss: 1.2087
# Epoch 8/15
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 11s 32ms/step - accuracy: 0.7143 - loss: 0.7784 - val_accuracy: 0.5663 - val_loss: 1.2699
# Epoch 9/15
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 11s 32ms/step - accuracy: 0.7358 - loss: 0.7389 - val_accuracy: 0.5606 - val_loss: 1.2600
# Epoch 10/15
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 11s 33ms/step - accuracy: 0.7563 - loss: 0.6590 - val_accuracy: 0.5823 - val_loss: 1.4375
# Epoch 11/15
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 11s 32ms/step - accuracy: 0.7722 - loss: 0.6288 - val_accuracy: 0.5723 - val_loss: 1.4099
# Epoch 12/15
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 11s 33ms/step - accuracy: 0.7911 - loss: 0.5750 - val_accuracy: 0.5791 - val_loss: 1.3638
# Epoch 13/15
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 12s 35ms/step - accuracy: 0.8180 - loss: 0.5129 - val_accuracy: 0.5770 - val_loss: 1.5090
# Epoch 14/15
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 12s 33ms/step - accuracy: 0.8226 - loss: 0.4994 - val_accuracy: 0.5602 - val_loss: 1.6260
# Epoch 15/15
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 11s 32ms/step - accuracy: 0.8457 - loss: 0.4408 - val_accuracy: 0.5852 - val_loss: 1.4805

# %%
MODEL_PATH = "../models/mlp_normalized.keras"

model.save(MODEL_PATH)
